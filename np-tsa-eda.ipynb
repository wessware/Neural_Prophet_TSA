# %%
from neuralprophet import NeuralProphet
import pandas as pd

# %%
df = pd.read_csv('/kaggle/input/case-ih-time-series-data/data.csv', parse_dates = ['date'])

# %%
df.head(10)
# Out:
#         date  work  income
# 0 2021-09-30     2    2100
# 1 2021-10-03     1    3600
# 2 2021-10-04     1    4000
# 3 2021-10-05     1    7900
# 4 2021-10-06     1    7500
# 5 2021-10-07     1   10600
# 6 2021-10-08     1    6700
# 7 2021-10-09     3    5800
# 8 2021-10-10     1    6800
# 9 2021-10-11     3    8000

# %%
df = df[['date', 'income']]

# %%
df.head(5)
# Out:
#         date  income
# 0 2021-09-30    2100
# 1 2021-10-03    3600
# 2 2021-10-04    4000
# 3 2021-10-05    7900
# 4 2021-10-06    7500

# %%
plt  = df.plot(x='date', y='income', figsize=(15, 5))
